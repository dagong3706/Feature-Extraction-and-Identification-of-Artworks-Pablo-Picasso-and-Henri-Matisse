# %%
import pandas as pd
import os

import bokeh
from bokeh.io import output_notebook, curdoc, reset_output
from bokeh.plotting import figure, output_file, show, ColumnDataSource

import numpy as np
import scipy.special
# used to standardize plot size below
GLOBAL_WIDTH = 800
GLOBAL_HEIGHT = 600

# display notebooks inline
output_notebook() 
import bokeh.plotting as bk
from bokeh.models import Span, Label
from bokeh.layouts import row
from bokeh.sampledata.autompg import autompg as df
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1005">Loading BokehJS ...</span>
#     </div>

# %%
pp = pd.read_csv('../data/picasso.csv')
pp2 = pd.read_csv('../data/henri_dic.csv')
pp = pp.rename(columns={'Unnamed: 0': 'Picturesource', '0': 'Painting'})
pp2 = pp2.rename(columns={'Unnamed: 0': 'Picturesource', '0': 'Painting'})

# %%
picasso = pd.read_csv('../data/picasso_data.csv')
picasso['Painting'] = picasso['Painting'].apply(lambda x: x[2:-8])
picasso
# Out:
#                Picturesource  \
# 0    images-works-3437_s.jpg
# 1      images-works-56_s.jpg
# 2    images-works-1513_s.jpg
# 3    images-works-3570_s.jpg
# 4    images-works-1459_s.jpg
# ..                       ...
# 118  images-works-4053_s.jpg
# 119  images-works-2244_s.jpg
# 120  images-works-1760_s.jpg
# 121  images-works-2693_s.jpg
# 122  images-works-1702_s.jpg
#
#                                               Painting  Year  Portrait  \
# 0                                            maternity  1905       0.0
# 1    les demoiselles d'avignon (the young ladies of...  1907       1.0
# 2                                    portrait of woman  1938       1.0
# 3                                          naked woman  1902       1.0
# 4                                woman with a blue hat  1939       1.0
# ..                                                 ...   ...       ...
# 118                         seated woman in blue dress  1939       1.0
# 119                                profile female bust  1932       1.0
# 120                       woman sitting in an armchair  1941       1.0
# 121                              head and woman's hand  1921       1.0
# 122                         woman with hat (dora maar)  1938       1.0
#
#      RMS_contrast  AVG_entropy  RMS_contrast_log  AVG_entropy_log  \
# 0        0.271341     3.756512         -1.881822         1.909394
# 1        0.197231     5.041706         -2.342045         2.333912
# 2        0.191595     5.023209         -2.383869         2.328609
# 3        0.145416     5.223912         -2.781742         2.385131
# 4        0.262751     5.015289         -1.928229         2.326333
# ..            ...          ...               ...              ...
# 118      0.146214     4.933578         -2.773851         2.302634
# 119      0.261993     4.519896         -1.932402         2.176290
# 120      0.142179     4.642326         -2.814218         2.214848
# 121      0.202769     4.721895         -2.302092         2.239366
# 122      0.112868     4.625793         -3.147291         2.209701
#
#      erotic_charge
# 0         0.013786
# 1        -0.004066
# 2        -0.027630
# 3        -0.198306
# 4         0.199052
# ..             ...
# 118      -0.235608
# 119       0.121944
# 120      -0.299685
# 121      -0.031363
# 122      -0.468795
#
# [123 rows x 9 columns]

# %%
matisse = pd.read_csv('../data/matisse_data.csv')
matisse['Painting'] = matisse['Painting'].apply(lambda x: x[2:-8])
matisse
# Out:
#                       Picturesource  \
# 0       paintings-thmbnls150-bb.jpg
# 1       paintings-thmbnls150-bd.jpg
# 2       paintings-thmbnls150-bc.jpg
# 3       paintings-thmbnls150-cs.jpg
# 4       paintings-thmbnls150-dr.jpg
# 5       paintings-thmbnls150-zd.jpg
# 6   paintings-thmbnls150-hma308.jpg
# 7       paintings-thmbnls150-gk.jpg
# 8     paintings-orient_111_thmb.jpg
# 9       paintings-thmbnls150-cb.jpg
# 10    paintings-orient_129_thmb.jpg
# 11      paintings-thmbnls150-ea.jpg
# 12      paintings-thmbnls150-cc.jpg
# 13      paintings-thmbnls150-cd.jpg
# 14      paintings-thmbnls150-eq.jpg
# 15    paintings-orient_187_thmb.jpg
# 16      paintings-thmbnls150-ep.jpg
# 17    paintings-orient_189_thmb.jpg
# 18   paintings-thmbnls150-hma97.jpg
# 19    paintings-orient_185_thmb.jpg
# 20      paintings-thmbnls150-cj.jpg
# 21    paintings-orient_186_thmb.jpg
# 22      paintings-thmbnls150-eu.jpg
# 23    paintings-orient_183_thmb.jpg
# 24      paintings-thmbnls150-et.jpg
# 25      paintings-thmbnls150-ex.jpg
# 26      paintings-thmbnls150-ez.jpg
# 27    paintings-orient_193_thmb.jpg
# 28    paintings-orient_195_thmb.jpg
# 29      paintings-thmbnls150-ca.jpg
# 30      paintings-thmbnls150-fe.jpg
# 31    paintings-orient_199_thmb.jpg
# 32      paintings-thmbnls150-ff.jpg
# 33     paintings-orient_84_thmb.jpg
# 34    paintings-orient_197_thmb.jpg
# 35      paintings-thmbnls150-fh.jpg
# 36      paintings-thmbnls150-fi.jpg
# 37    paintings-orient_211_thmb.jpg
# 38      paintings-thmbnls150-ey.jpg
# 39      paintings-thmbnls150-fk.jpg
# 40      paintings-thmbnls150-fo.jpg
# 41      paintings-thmbnls150-fj.jpg
# 42      paintings-thmbnls150-fm.jpg
# 43      paintings-thmbnls150-fp.jpg
# 44      paintings-thmbnls150-zp.jpg
# 45      paintings-thmbnls150-bz.jpg
# 46      paintings-thmbnls150-fr.jpg
# 47      paintings-thmbnls150-fs.jpg
# 48      paintings-thmbnls150-dc.jpg
# 49      paintings-thmbnls150-gb.jpg
# 50      paintings-thmbnls150-gc.jpg
# 51      paintings-thmbnls150-gd.jpg
# 52      paintings-thmbnls150-gn.jpg
# 53      paintings-thmbnls150-fz.jpg
# 54      paintings-thmbnls150-dh.jpg
#
#                                            Painting  Year  Portrait  \
# 0                                    standing model  1901       1.0
# 1                      nude with a white wash towel  1903       1.0
# 2                                         carmelina  1903       1.0
# 3       the green line (portrait of madame matisse)  1905       0.0
# 4                 woman with a hat (madame matisse)  1905       0.0
# 5                                         blue nude  1905       0.0
# 6                              woman with a parasol  1905       1.0
# 7                             interior at collioure  1906       1.0
# 8                                woman on a terrace  1907       1.0
# 9                                    woman in green  1909       1.0
# 10                                        rose nude  1909       1.0
# 11                                 the conversation  1911       0.0
# 12                     laurette with a white blouse  1916       1.0
# 13    laurette with a green dress, black background  1916       1.0
# 14                                the three sisters  1916       1.0
# 15                                  head of lorette  1917       1.0
# 16                            woman at the fountain  1917       1.0
# 17                                aicha and lorette  1917       1.0
# 18                        the painter and his model  1917       1.0
# 19                         lorette with a red dress  1917       1.0
# 20                           interior with a violin  1918       1.0
# 21                             woman with dark hair  1918       1.0
# 22                        woman with a flowered hat  1919       1.0
# 23                        woman with oriental dress  1919       1.0
# 24                         the artist and his model  1919       1.0
# 25                          girl with a green dress  1921       1.0
# 26                         odalisque with red pants  1921       1.0
# 27          odalisque with a green plant and screen  1923       1.0
# 28                                        odalisque  1923       1.0
# 29                   moorish woman with upheld arms  1923       1.0
# 30                          odalisque with magnolia  1924       1.0
# 31                                        odalisque  1925       1.0
# 32                      odalisque with a tambourine  1926       1.0
# 33                                        odalisque  1926       1.0
# 34                                        odalisque  1926       1.0
# 35                         a nude lying on her back  1927       1.0
# 36                        odalisque with gray pants  1927       1.0
# 37                         woman with a white dress  1934       1.0
# 38        decorative figure on an ornamental ground  1934       1.0
# 39        decorative figure on an ornamental ground  1934       1.0
# 40                               a pink nude seated  1935       1.0
# 41             an nude dtanding before an open door  1936       1.0
# 42                 a nude with her heel on her knee  1936       1.0
# 43                 woman on a sofa, yellow and blue  1936       1.0
# 44                        nude on a blue background  1936       1.0
# 45  woman in blue / the large blue robe and mimosas  1936       1.0
# 46                      helen with a precious stone  1937       1.0
# 47           woman in yellow and blue with a guitar  1939       1.0
# 48                    young girl with a yellow sofa  1940       1.0
# 49                   interior with an etruscan vase  1940       1.0
# 50                                        two girls  1941       1.0
# 51                                woman with a veil  1942       1.0
# 52                       woman on a dark background  1942       1.0
# 53                               young girl in rose  1942       1.0
# 54                                  sunlit interior  1942       1.0
#
#     RMS_contrast  AVG_entropy  RMS_contrast_log  AVG_entropy_log  \
# 0       0.161886     4.809607         -2.626949         2.265919
# 1       0.158400     4.845199         -2.658352         2.276556
# 2       0.198444     5.141422         -2.333199         2.362168
# 3       0.173126     5.002342         -2.530106         2.322604
# 4       0.202277     5.171739         -2.305596         2.370650
# 5       0.229223     5.315706         -2.125175         2.410261
# 6       0.118171     5.196761         -3.081048         2.377613
# 7       0.164125     5.229967         -2.607129         2.386802
# 8       0.174502     5.026028         -2.518683         2.329419
# 9       0.197941     4.767572         -2.336854         2.253255
# 10      0.163515     4.789169         -2.612504         2.259775
# 11      0.132826     4.405845         -2.912389         2.139419
# 12      0.214300     4.710915         -2.222293         2.236007
# 13      0.133440     4.107550         -2.905741         2.038278
# 14      0.262437     4.978472         -1.929956         2.315703
# 15      0.185316     4.161004         -2.431939         2.056932
# 16      0.227410     5.059293         -2.136634         2.338936
# 17      0.195371     4.647582         -2.355709         2.216480
# 18      0.205595     4.793155         -2.282121         2.260976
# 19      0.178609     4.998196         -2.485120         2.321408
# 20      0.220780     4.849875         -2.179316         2.277947
# 21      0.143079     4.473422         -2.805113         2.161379
# 22      0.202234     5.151225         -2.305900         2.364916
# 23      0.165929     5.033920         -2.591359         2.331682
# 24      0.154368     5.429749         -2.695554         2.440886
# 25      0.212383     5.108932         -2.235258         2.353022
# 26      0.178209     5.123990         -2.488358         2.357268
# 27      0.153526     4.904268         -2.703444         2.294038
# 28      0.144058     5.063071         -2.795279         2.340013
# 29      0.197378     5.347490         -2.340967         2.418862
# 30      0.195734     5.079973         -2.353031         2.344821
# 31      0.122230     4.882069         -3.032325         2.287493
# 32      0.210307     5.121163         -2.249433         2.356471
# 33      0.207356     5.481119         -2.269816         2.454470
# 34      0.156687     5.258520         -2.674040         2.394657
# 35      0.227725     5.538950         -2.134638         2.469612
# 36      0.226334     5.151394         -2.143472         2.364963
# 37      0.170109     4.962816         -2.555471         2.311159
# 38      0.200619     5.500098         -2.317467         2.459457
# 39      0.210729     5.015897         -2.246542         2.326508
# 40      0.169264     4.915487         -2.562657         2.297334
# 41      0.233704     5.301205         -2.097247         2.406320
# 42      0.201845     5.125277         -2.308680         2.357630
# 43      0.218666     5.115614         -2.193196         2.354907
# 44      0.239073     4.759942         -2.064478         2.250944
# 45      0.232393     4.985256         -2.105360         2.317667
# 46      0.181622     5.427858         -2.460992         2.440383
# 47      0.151067     4.765329         -2.726739         2.252576
# 48      0.215333     5.034138         -2.215360         2.331745
# 49      0.209906     5.383191         -2.252188         2.428461
# 50      0.213343     5.096634         -2.228755         2.349545
# 51      0.150987     5.012162         -2.727505         2.325433
# 52      0.224307     5.131280         -2.156454         2.359319
# 53      0.156125     4.379388         -2.679228         2.130729
# 54      0.186961     5.368946         -2.419190         2.424639
#
#     erotic_charge
# 0       -0.180515
# 1       -0.190898
# 2        0.014484
# 3       -0.103751
# 4        0.032527
# 5        0.142543
# 6       -0.351717
# 7       -0.110163
# 8       -0.094632
# 9       -0.041800
# 10      -0.176364
# 11      -0.386485
# 12       0.006857
# 13      -0.433731
# 14       0.192874
# 15      -0.187504
# 16       0.101151
# 17      -0.069614
# 18      -0.010573
# 19      -0.081856
# 20       0.049316
# 21      -0.321867
# 22       0.029508
# 23      -0.129838
# 24      -0.127334
# 25       0.058882
# 26      -0.065545
# 27      -0.204703
# 28      -0.227633
# 29       0.038947
# 30      -0.004105
# 31      -0.372416
# 32       0.053519
# 33       0.092327
# 34      -0.139691
# 35       0.167487
# 36       0.110745
# 37      -0.122156
# 38       0.070995
# 39       0.039983
# 40      -0.132661
# 41       0.154537
# 42       0.024475
# 43       0.080855
# 44       0.093233
# 45       0.106153
# 46      -0.010305
# 47      -0.237081
# 48       0.058192
# 49       0.088137
# 50       0.060395
# 51      -0.201036
# 52       0.101432
# 53      -0.274250
# 54       0.002724

# %%
# pdf = pd.read_csv('../data/picasso_data.csv')
# mdf = pd.read_csv('../data/matisse_data.csv')
# pdf['Picturesource'] = pdf['Picturesource'].apply(lambda x: os.path.join(os.pardir, 'data/picasso', x))
# pdf['Painting'] = pp['Painting'].apply(lambda x: x[2:-8])
# pdfp=pdf[pdf["Portrait"]==1]
# mdf['Picturesource'] = mdf['Picturesource'].apply(lambda x: os.path.join(os.pardir, 'data/henri-matisse', x))
# mdf['Painting'] = pp2['Painting'].apply(lambda x: x[2:-8])
# mdfp=mdf[mdf["Portrait"]==1]

# %% [markdown]
# **Compare the log RMS of paintings of two artists**

# %%
picasso_RMS_contrast_log = sns.distplot(picasso.RMS_contrast_log, color = 'crimson')
matisse_RMS_contrast_log = sns.distplot(matisse.RMS_contrast_log, color = 'blue')
# display(a,b)

# %%
picasso_erotic = sns.distplot(picasso.erotic_charge, color = 'red')
matisse_erotic = sns.distplot(matisse.erotic_charge, color = 'blue')

# %%
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
# f, ax = plt.subplots(figsize=(6.5, 6.5))
# sns.scatterplot(x="Year", y="RMS_contrast_log",
#                 hue="clarity", size="depth",
#                 palette="ch:r=-.2,d=.3_r",
#                 hue_order=clarity_ranking,
#                 sizes=(1, 8), linewidth=0,
#                 data=picasso, ax =ax)
sns.scatterplot(x='Year', y = 'RMS_contrast_log',data = picasso)

# %%
sns.scatterplot(x='Year', y = 'RMS_contrast_log',data = matisse)

# %%
p_meanRMS=pdfp.groupby('Year').mean()
m_meanRMS=mdfp.groupby('Year').mean()

# %%
p_meanRMS
# Out:
#       Portrait  RMS_contrast  AVG_entropy  RMS_contrast_log  AVG_entropy_log  \
# Year
# 1902       1.0      0.145416     5.223912         -2.781742         2.385131
# 1904       1.0      0.176540     4.971960         -2.509145         2.309078
# 1905       1.0      0.206314     3.807211         -2.322416         1.868895
# 1906       1.0      0.132106     4.854955         -2.920233         2.279458
# 1907       1.0      0.216379     4.828927         -2.214041         2.270301
# 1908       1.0      0.128469     5.207494         -2.960510         2.380589
# 1909       1.0      0.159623     4.781778         -2.682749         2.250148
# 1914       1.0      0.204644     4.608837         -2.288813         2.204403
# 1918       1.0      0.197213     5.035919         -2.342172         2.332255
# 1920       1.0      0.171775     4.810710         -2.560152         2.266168
# 1921       1.0      0.202769     4.721895         -2.302092         2.239366
# 1923       1.0      0.170916     4.900609         -2.557273         2.292874
# 1927       1.0      0.243352     4.185441         -2.038885         2.065380
# 1928       1.0      0.132071     4.442832         -2.920616         2.151479
# 1930       1.0      0.263163     4.286938         -1.925973         2.099948
# 1932       1.0      0.255059     4.633503         -2.003217         2.209666
# 1934       1.0      0.275647     4.878675         -1.859107         2.286489
# 1935       1.0      0.195741     5.032827         -2.352984         2.331369
# 1936       1.0      0.219960     4.642717         -2.240926         2.209855
# 1937       1.0      0.264777     4.798067         -1.926751         2.257929
# 1938       1.0      0.217285     4.832740         -2.250624         2.269062
# 1939       1.0      0.217251     4.735524         -2.251351         2.236307
# 1940       1.0      0.236721     5.086348         -2.091673         2.344253
# 1941       1.0      0.228928     4.583171         -2.204668         2.188506
# 1942       1.0      0.212155     4.419870         -2.238798         2.143994
#
#       erotic_charge
# Year
# 1902      -0.198306
# 1904      -0.100033
# 1905      -0.226761
# 1906      -0.320388
# 1907       0.028130
# 1908      -0.289960
# 1909      -0.216301
# 1914      -0.042205
# 1918      -0.004959
# 1920      -0.146992
# 1921      -0.031363
# 1923      -0.132199
# 1927       0.013247
# 1928      -0.384568
# 1930       0.086987
# 1932       0.103224
# 1934       0.213691
# 1935      -0.010807
# 1936      -0.015535
# 1937       0.165589
# 1938       0.009219
# 1939      -0.007522
# 1940       0.126290
# 1941      -0.008081
# 1942      -0.047402

# %%
bins=np.linspace(min(pdfp['RMS_contrast']), max(pdfp['RMS_contrast']), 7)
pdfp['RMS_contrast'].plot.hist(bins=bins, rwidth=0.9, label="Picasso")
mdfp['RMS_contrast'].plot.hist(bins=bins, rwidth=0.9, label="Matisse")
plt.title("Picasso's RMS Contrast Value vs. Matisse's RMS Contrast Value")
plt.xlabel('RMS Contrast Value')
plt.ylabel('Count(#)')
# Out:
# Text(0, 0.5, 'Count(#)')

# %%
x = p_meanRMS.index
y = p_meanRMS['RMS_contrast']

x2 = m_meanRMS.index
y2 = m_meanRMS['RMS_contrast']


output_notebook()

p = figure(title="Compare Mean RMS contrast overyear", x_axis_label='Year', y_axis_label='Mean_RMS_contrast')

p.line(x, y, legend_label="Picasso_Mean_RMS_contrast_overyear", line_width=2)
p.line(x2, y2, legend_label="Matisse_Mean_RMS_contrast_overyear", line_width=2,line_color="#f46d43")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9400">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a1e0e6c3-93e1-47d7-8ba7-65b36a446b04" data-root-id="9401"></div>

# %%
x = p_meanRMS.index
y = p_meanRMS['erotic_charge']

x2 = m_meanRMS.index
y2 = m_meanRMS['erotic_charge']


# display inline
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="Compare Erotic Charge overyear", x_axis_label='Year', y_axis_label='erotic_charge')

# add a line renderer with legend and line thickness
p.line(x, y, legend_label="Picasso_erotic_charge_overyear", line_width=2)
p.line(x2, y2, legend_label="Matisse_erotic_charge_overyear", line_width=2,line_color="#f46d43")

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="42046">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e43a08ac-a2bd-4c1f-9832-85aea9874eec" data-root-id="42047"></div>

# %%
x = pdfp['RMS_contrast']
y = pdfp['AVG_entropy']

x2 = mdfp['RMS_contrast']
y2 = mdfp['AVG_entropy']

# plotting
p = figure(title="Picasso & Matisso's paintings' RMS contrast value vs. AVG_entropy",plot_width=GLOBAL_WIDTH, plot_height=GLOBAL_HEIGHT, x_axis_label='RMS_contrast', y_axis_label='AVG_entropy')

# add a circle renderer with a size, color, and alpha
p.circle(x, y, size=5, color="red", alpha=0.9,legend_label="Picasso")
p.circle(x2, y2, size=5, color="blue", alpha=0.9,legend_label="Matisso")

# show the results
show(p)
# Out:
#   <div class="bk-root" id="5e41da79-5e87-4db6-86a4-b6906d520134" data-root-id="38477"></div>

# %%
source = ColumnDataSource(data=dict(
    x=pdfp['Year'],
    y=pdfp['RMS_contrast_log'],
    desc=pdfp['Painting'],
    imgs=pdfp['Picturesource'],
    fonts=[
        '<i>italics</i>' for i in range(len(pdfp.index))
    ]
))

source2 = ColumnDataSource(data=dict(
    x2=mdfp['Year'],
    y2=mdfp['RMS_contrast_log'],
    desc=mdfp['Painting'],
    imgs=mdfp['Picturesource'],
    fonts=[
        '<i>italics</i>' for i in range(len(mdfp.index))
    ]
))


TOOLTIPS = """
    <div>
        <div>
            <img
                src="@imgs" height="42" alt="@imgs" width="42"
                style="float: left; margin: 0px 15px 15px 0px;"
                border="2"
            ></img>
        </div>
        <div>
            <span style="font-size: 17px; font-weight: bold;">@desc</span>
            <span style="font-size: 15px; color: #966;">[$index]</span>
        </div>
        <div>
            <span style="font-size: 15px;">Painting Year:</span>
            <span style="font-size: 10px; color: #696;">$x{0}</span>
        </div>
        <div>
            <span style="font-size: 15px;">RMS Contrast Log Value:</span>
            <span style="font-size: 10px; color: #696;">$y</span>
        </div>
    </div>
"""
TOOLTIPS2 = """
    <div>
        <div>
            <span style="font-size: 15px;">The year they met each other.</span>
        </div>
    </div>
"""

p = figure(plot_width=GLOBAL_WIDTH, plot_height=GLOBAL_HEIGHT, tooltips=TOOLTIPS,
           title="Painings' RMS contrast log Value Throughout Year",x_axis_label='Year', y_axis_label='RMS_contrast_log')

p.circle('x', 'y', size=10, source=source,color="red",legend_label="Picasso")
p.circle('x2', 'y2', size=10, source=source2,legend_label="Matisso")
vline = Span(location=1906, dimension='height', line_color='black', line_width=1,line_dash="dashed")
p.renderers.extend([vline])
my_label = Label(x=1906, y=500, y_units='screen', text='Year 1906 when they met each other')
p.add_layout(my_label)
show(p)
# Out:
#   <div class="bk-root" id="f2210513-e3bc-44c9-8744-d3fb75af489a" data-root-id="41137"></div>

# %%
source = ColumnDataSource(data=dict(
    x=pdfp['Year'],
    y=pdfp['AVG_entropy_log'],
    desc=pdfp['Painting'],
    imgs=pdfp['Picturesource'],
    fonts=[
        '<i>italics</i>' for i in range(len(pdfp.index))
    ]
))

source2 = ColumnDataSource(data=dict(
    x2=mdfp['Year'],
    y2=mdfp['AVG_entropy_log'],
    desc=mdfp['Painting'],
    imgs=mdfp['Picturesource'],
    fonts=[
        '<i>italics</i>' for i in range(len(mdfp.index))
    ]
))


TOOLTIPS = """
    <div>
        <div>
            <img
                src="@imgs" height="42" alt="@imgs" width="42"
                style="float: left; margin: 0px 15px 15px 0px;"
                border="2"
            ></img>
        </div>
        <div>
            <span style="font-size: 17px; font-weight: bold;">@desc</span>
            <span style="font-size: 15px; color: #966;">[$index]</span>
        </div>
        <div>
            <span style="font-size: 15px;">Painting Year:</span>
            <span style="font-size: 10px; color: #696;">$x{0}</span>
        </div>
        <div>
            <span style="font-size: 15px;">AVG Entropy Log</span>
            <span style="font-size: 10px; color: #696;">$y</span>
        </div>
    </div>
"""
TOOLTIPS2 = """
    <div>
        <div>
            <span style="font-size: 15px;">The year they met each other.</span>
        </div>
    </div>
"""

p = figure(plot_width=GLOBAL_WIDTH, plot_height=GLOBAL_HEIGHT, tooltips=TOOLTIPS,
           title="Painings' AVG Entropy Log Value Throughout Year",x_axis_label='Year', y_axis_label='AVG_entropy_log')

p.circle('x', 'y', size=10, source=source,color="red",legend_label="Picasso")
p.circle('x2', 'y2', size=10, source=source2,legend_label="Matisso")
vline = Span(location=1906, dimension='height', line_color='black', line_width=1,line_dash="dashed")
p.renderers.extend([vline])
my_label = Label(x=1906, y=500, y_units='screen', text='Year 1906 when they met each other')
p.add_layout(my_label)
show(p)
# Out:
#   <div class="bk-root" id="238e54a1-11c9-493a-9353-dab847fcf1a3" data-root-id="40239"></div>

# %%
source = ColumnDataSource(data=dict(
    x=pdfp['Year'],
    y=pdfp['erotic_charge'],
    desc=pdfp['Painting'],
    imgs=pdfp['Picturesource'],
    fonts=[
        '<i>italics</i>' for i in range(len(pdfp.index))
    ]
))

source2 = ColumnDataSource(data=dict(
    x2=mdfp['Year'],
    y2=mdfp['erotic_charge'],
    desc=mdfp['Painting'],
    imgs=mdfp['Picturesource'],
    fonts=[
        '<i>italics</i>' for i in range(len(mdfp.index))
    ]
))


TOOLTIPS = """
    <div>
        <div>
            <img
                src="@imgs" height="42" alt="@imgs" width="42"
                style="float: left; margin: 0px 15px 15px 0px;"
                border="2"
            ></img>
        </div>
        <div>
            <span style="font-size: 17px; font-weight: bold;">@desc</span>
            <span style="font-size: 15px; color: #966;">[$index]</span>
        </div>
        <div>
            <span style="font-size: 15px;">Painting Year:</span>
            <span style="font-size: 10px; color: #696;">$x{0}</span>
        </div>
        <div>
            <span style="font-size: 15px;">Erotic Charge Value:</span>
            <span style="font-size: 10px; color: #696;">$y{0.000}</span>
        </div>
    </div>
"""
TOOLTIPS2 = """
    <div>
        <div>
            <span style="font-size: 15px;">The year they met each other.</span>
        </div>
    </div>
"""

p = figure(plot_width=GLOBAL_WIDTH, plot_height=GLOBAL_HEIGHT, tooltips=TOOLTIPS,
           title="Painings' Erotic Charge Value Throughout Year",x_axis_label='Year', y_axis_label='erotic_charge')

p.circle('x', 'y', size=10, source=source,color="red",legend_label="Picasso")
p.circle('x2', 'y2', size=10, source=source2,legend_label="Matisso")
vline = Span(location=1906, dimension='height', line_color='black', line_width=1,line_dash="dashed")
p.renderers.extend([vline])
my_label = Label(x=1906, y=500, y_units='screen', text='Year 1906 when they met each other')
p.add_layout(my_label)
show(p)
# Out:
#   <div class="bk-root" id="de1f79ee-a2d5-4dd1-86bb-587561a821f5" data-root-id="39351"></div>
